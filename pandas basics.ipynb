# %% [markdown]
# # Use the Automobiles Dataset.

# %% [markdown]
# # 1) From given data set print first and last five rows

# %%
import pandas as pd
df=pd.read_csv('Automobile_data.csv')
obj=pd.DataFrame(df)
print('first five lines\n\n',df.head(5))
print('\nlast five lines\n\n',df.tail(5))
# Out:
# first five lines
#
#     index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
#
# last five lines
#
#      index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# ...

# %% [markdown]
# # 2) Print All Toyota Cars details (hint: use groupby function)

# %%
import pandas as pd
df=pd.read_csv('Automobile_data.csv')
obj=pd.DataFrame(df)
obj.groupby('company').mean()
obj.groupby(['company']).mean()
# Out:
#                index  wheel-base      length  horsepower  average-mileage  \
# company
# alfa-romero     1.00   90.566667  169.600000  125.333333        20.333333
# audi            4.50  101.200000  180.800000  109.250000        20.000000
# bmw            12.00  103.433333  185.033333  144.833333        19.000000
# chevrolet      17.00   92.466667  151.933333   62.666667        41.000000
# dodge          19.50   93.700000  157.300000   68.000000        31.000000
# honda          28.00   96.500000  167.200000   92.333333        26.333333
# isuzu          31.00   94.433333  160.833333   72.666667        33.333333
# jaguar         34.00  109.333333  196.966667  204.666667        14.333333
# mazda          38.60   95.900000  164.260000   75.400000        28.000000
# mercedes-benz  45.50  113.225000  197.275000  153.500000        18.000000
# mitsubishi     50.50   95.000000  164.850000   78.000000        29.500000
# ...

# %% [markdown]
# # 3) Count total cars per company (by using value_counts function)

# %%
import pandas as pd
df=pd.read_csv('Automobile_data.csv')
obj=pd.DataFrame(df)
y=obj.count()
y['company']
# Out:
# 61

# %% [markdown]
# # 4) Find each company’s Higesht price car. (hint: Groupby function and then apply .max function)

# %%
import pandas as pd
df=pd.read_csv('Automobile_data.csv')
obj1=pd.DataFrame(df)
x=obj1.groupby('price').max()
x
# Out:
#          index        company   body-style  wheel-base  length engine-type  \
# price
# 5151.0      16      chevrolet    hatchback        88.4   141.1           l
# 5195.0      36          mazda    hatchback        93.1   159.1         ohc
# 5348.0      66         toyota    hatchback        95.7   158.7         ohc
# 5389.0      49     mitsubishi    hatchback        93.7   157.3         ohc
# 6095.0      37          mazda    hatchback        93.1   159.1         ohc
# 6189.0      50     mitsubishi    hatchback        93.7   157.3         ohc
# 6229.0      20          dodge    hatchback        93.7   157.3         ohc
# 6295.0      17      chevrolet    hatchback        94.5   155.9         ohc
# 6338.0      67         toyota    hatchback        95.7   158.7         ohc
# 6377.0      19          dodge    hatchback        93.7   157.3         ohc
# 6488.0      68         toyota    hatchback        95.7   158.7         ohc
# ...

# %% [markdown]
# # 5)Find the average mileage of each car making company (hint: Groupby function and then apply .mean function)

# %%
import pandas as pd
df=pd.read_csv('Automobile_data.csv')
obj=pd.DataFrame(df)
x=obj.groupby('average-mileage')

x.mean()
# Out:
#                      index  wheel-base      length  horsepower         price
# average-mileage
# 13               35.000000  102.000000  191.700000  262.000000  36000.000000
# 14               46.500000  116.450000  203.650000  184.000000  43180.000000
# 15               27.333333  112.000000  198.733333  178.000000  34893.333333
# 16               13.500000  103.500000  191.400000  182.000000  36037.500000
# 17               56.250000   93.175000  170.625000  200.750000  27633.666667
# 18                4.000000   99.400000  176.600000  115.000000  17450.000000
# 19               29.800000  101.000000  182.720000  136.400000  15983.800000
# 21                4.000000   92.800000  171.466667  114.333333  16988.333333
# 22               44.500000  110.000000  190.900000  123.000000  26900.000000
# 23               48.500000  102.750000  182.800000  107.500000  14927.500000
# 24               20.333333   96.866667  174.233333   93.666667  11226.666667
# ...

# %% [markdown]
# # 6) Sort all cars by Price column (hint: using sort_values function).

# %%
x=obj.sort_values(by='price')
x.head(60)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 13     16      chevrolet    hatchback        88.4   141.1           l
# 27     36          mazda    hatchback        93.1   159.1         ohc
# 48     66         toyota    hatchback        95.7   158.7         ohc
# 36     49     mitsubishi    hatchback        93.7   157.3         ohc
# 28     37          mazda    hatchback        93.1   159.1         ohc
# 37     50     mitsubishi    hatchback        93.7   157.3         ohc
# 17     20          dodge    hatchback        93.7   157.3         ohc
# 14     17      chevrolet    hatchback        94.5   155.9         ohc
# 49     67         toyota    hatchback        95.7   158.7         ohc
# 16     19          dodge    hatchback        93.7   157.3         ohc
# 50     68         toyota    hatchback        95.7   158.7         ohc
# 15     18      chevrolet        sedan        94.5   158.8         ohc
# ...

# %% [markdown]
# # 7) Check for the null values for entire dataset.

# %%
nan=obj.isnull()
print(nan.to_string())
# Out:
#     index  company  body-style  wheel-base  length  engine-type  num-of-cylinders  horsepower  average-mileage  price
# 0   False    False       False       False   False        False             False       False            False  False
# 1   False    False       False       False   False        False             False       False            False  False
# 2   False    False       False       False   False        False             False       False            False  False
# 3   False    False       False       False   False        False             False       False            False  False
# 4   False    False       False       False   False        False             False       False            False  False
# 5   False    False       False       False   False        False             False       False            False  False
# 6   False    False       False       False   False        False             False       False            False  False
# ...

# %% [markdown]
# # 8) Use Crime dataset.

# %% [raw]
# A) do the plottings like plottings like histogram, boxplot, scatterplot, barplot, piechart,dot chart.

# %%
import pandas as pd
df=pd.read_csv('crime_data.csv')
obj=pd.DataFrame(df)
obj
# Out:
#              names  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
import matplotlib.pyplot as plt
obj.plot.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
obj.boxplot()
plt.show()

# %%
import matplotlib.pyplot as plt
obj.plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
obj.plot.pie(y='Murder')
plt.show()

# %%
import matplotlib.pyplot as plt
obj.plot.scatter(x='Murder',y="Rape")
plt.show()

# %% [markdown]
# # 9) use mtcars dataset.

# %% [raw]
# A) delete/ drop rows-10 to 15 of all columns

# %%
import pandas as pd
df=pd.read_csv('mtcars.csv')
df=pd.DataFrame(df)
print(df)
df=df.drop(df[df['sl.no']==10].index) 
df=df.drop(df[df['sl.no']==11].index) 
df=df.drop(df[df['sl.no']==12].index) 
df=df.drop(df[df['sl.no']==13].index) 
df=df.drop(df[df['sl.no']==14].index) 
df=df.drop(df[df['sl.no']==15].index) 
print('\n\n\t\tafter droping the rows\n\n')
print("\n\n",df)
# Out:
#     sl.no   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0       1  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1       2  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2       3  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3       4  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4       5  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5       6  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6       7  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7       8  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8       9  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9      10  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10     11  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11     12  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# ...

# %% [raw]
# B)drop the VOL column

# %%
import pandas as pd
df=pd.read_csv("mtcars.csv")
df=pd.DataFrame(df)
df1=df.drop(["vs"],axis=1)
print(df1)
# Out:
#     sl.no   mpg  cyl   disp   hp  drat     wt   qsec  am  gear  carb
# 0       1  21.0    6  160.0  110  3.90  2.620  16.46   1     4     4
# 1       2  21.0    6  160.0  110  3.90  2.875  17.02   1     4     4
# 2       3  22.8    4  108.0   93  3.85  2.320  18.61   1     4     1
# 3       4  21.4    6  258.0  110  3.08  3.215  19.44   0     3     1
# 4       5  18.7    8  360.0  175  3.15  3.440  17.02   0     3     2
# 5       6  18.1    6  225.0  105  2.76  3.460  20.22   0     3     1
# 6       7  14.3    8  360.0  245  3.21  3.570  15.84   0     3     4
# 7       8  24.4    4  146.7   62  3.69  3.190  20.00   0     4     2
# 8       9  22.8    4  140.8   95  3.92  3.150  22.90   0     4     2
# 9      10  19.2    6  167.6  123  3.92  3.440  18.30   0     4     4
# 10     11  17.8    6  167.6  123  3.92  3.440  18.90   0     4     4
# 11     12  16.4    8  275.8  180  3.07  4.070  17.40   0     3     3
# 12     13  17.3    8  275.8  180  3.07  3.730  17.60   0     3     3
# ...

# %% [markdown]
# # 10) Use Bank Dataset.

# %% [raw]
# A) change all the categorical columns into numerical by creating Dummies and using label encoder.

# %%
import pandas as pd
df=pd.read_csv('bank-full.csv')
df=pd.DataFrame(df)
print(df.head(1))
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...

# %%
df.columns=['age','job','marital','education','default','balance','housing','loan','contact','day','month','dyration','pdays','privous','putcome']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-6dcce637f297> in <module>
# ----> 1 df.columns=['age','job','marital','education','default','balance','housing','loan','contact','day','month','dyration','pdays','privous','putcome']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# ...
